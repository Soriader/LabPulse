# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/raw/samples.csv')

print(df.columns)

df['value_clean'] = df['value'].replace(['error', 'bad_reading'], np.nan)

df['value_clean'] = df['value_clean'].str.replace(',', '.', regex=False)

df['value_num'] = pd.to_numeric(df['value_clean'], errors='coerce')


group_by_product = df.groupby(["product", "parameter"])["value_num"].agg([
    'count', 'mean', 'std', 'min', 'max', 'median'])

nan_details = df[df['value_num'].isna()].groupby(['product', 'parameter']).size().reset_index(name='nan_details')

print(nan_details)
# Out:
# Index(['sample_id', 'product', 'parameter', 'value', 'unit', 'date'], dtype='str')
# product   parameter
# Diesel    Water        1
# Gasoline  Ash          1
#           Viscosity    1
# HSFO      Viscosity    1
#           Water        1
# JetA1     Ash          1
# dtype: int64
